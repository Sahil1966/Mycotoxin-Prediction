# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler

from src.data_preprocessing.preprocessing import DataPreprocessor
from src.data_preprocessing.feature_engineering import FeatureEngineering

# Set plot style
sns.set(style="whitegrid")

# Path to dataset
data_path = "C:\\Users\\sahil\\Desktop\\Mycotoxin Prediction\\data\\MLE-Assignment.csv"

# Initialize Preprocessor
preprocessor = DataPreprocessor(data_path)

# Load Data
preprocessor.load_data()

# Explore Data
preprocessor.explore_data()

# Preprocess Data (handling missing values)
cleaned_df = preprocessor.preprocess_data()

# Apply Feature Engineering
feature_engineer = FeatureEngineering(cleaned_df)

# Run feature engineering steps
feature_engineer.run_feature_engineering()

# Display first few rows after feature engineering
print("First few rows after feature engineering:")
print(feature_engineer.df.head())

# Save the processed data for model training
processed_data_path = "C:/Users/sahil/Desktop/Mycotoxin Prediction/data/processed_data.csv"
feature_engineer.df.to_csv(processed_data_path, index=False)
print(f"Processed data saved to {processed_data_path}")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Columns: 450 entries, hsi_id to vomitoxin_ppb
# dtypes: float64(449), object(1)
# memory usage: 1.7+ MB
# None
#                 0           1           2           3           4           5  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     0.443118    0.440761    0.433814    0.426122    0.418990    0.412432
# std      0.044719    0.045520    0.045764    0.046070    0.045405    0.044727
# min      0.311182    0.295321    0.284064    0.282054    0.296702    0.286860
# 25%      0.410456    0.404310    0.397038    0.389029    0.382102    0.377157
# 50%      0.449105    0.442651    0.434215    0.425074    0.417075    0.411872
# 75%      0.480245    0.478822    0.473158    0.464947    0.459232    0.452198
# ...
